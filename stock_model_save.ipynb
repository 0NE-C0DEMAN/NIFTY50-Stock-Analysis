# %%
# !pip install streamlit==1.8.1
# Out:
# Collecting streamlit==1.8.1
#   Downloading streamlit-1.8.1-py2.py3-none-any.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 28.9 MB/s
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit==1.8.1) (21.3)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 52.5 MB/s
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit==1.8.1) (4.11.3)
# Collecting tzlocal
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (9.0.1)
# Collecting watchdog; platform_system != "Darwin"
#   Downloading watchdog-2.1.7-py3-none-manylinux2014_x86_64.whl (76 kB)
#      |████████████████████████████████| 76 kB 10.4 MB/s
# Requirement already satisfied: click<8.1,>=7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (8.0.4)
# Requirement already satisfied: python-dateutil in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit==1.8.1) (2.8.2)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (2.27.1)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: tornado>=5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit==1.8.1) (6.1)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit==1.8.1) (4.1.1)
# Requirement already satisfied: pandas>=0.21.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (1.2.5)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (1.21.5)
# Requirement already satisfied: altair>=3.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (4.1.0)
# Requirement already satisfied: attrs in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit==1.8.1) (21.4.0)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 93.5 MB/s
# Requirement already satisfied: cachetools>=4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (5.0.0)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 70.2 MB/s
# Requirement already satisfied: pyarrow in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (7.0.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 56.6 MB/s
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit==1.8.1) (3.19.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from packaging->streamlit==1.8.1) (3.0.7)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 4.5 MB/s
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata>=1.4->streamlit==1.8.1) (3.7.0)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo; python_version < "3.9"
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-manylinux1_x86_64.whl (70 kB)
#      |████████████████████████████████| 70 kB 19.2 MB/s
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil->streamlit==1.8.1) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->streamlit==1.8.1) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->streamlit==1.8.1) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->streamlit==1.8.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->streamlit==1.8.1) (2021.10.8)
# Requirement already satisfied: decorator>=3.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from validators->streamlit==1.8.1) (5.1.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas>=0.21.0->streamlit==1.8.1) (2022.1)
# Requirement already satisfied: entrypoints in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from altair>=3.2.0->streamlit==1.8.1) (0.4)
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from altair>=3.2.0->streamlit==1.8.1) (3.0.3)
# Requirement already satisfied: toolz in /shared-libs/python3.7/py/lib/python3.7/site-packages (from altair>=3.2.0->streamlit==1.8.1) (0.11.2)
# Requirement already satisfied: jsonschema in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from altair>=3.2.0->streamlit==1.8.1) (3.2.0)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 83.8 MB/s
# Requirement already satisfied: traitlets>=4.3.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1) (4.3.3)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1) (5.5.5)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting tzdata; python_version >= "3.6"
#   Downloading tzdata-2022.1-py2.py3-none-any.whl (339 kB)
#      |████████████████████████████████| 339 kB 63.9 MB/s
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2->altair>=3.2.0->streamlit==1.8.1) (2.1.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit==1.8.1) (47.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit==1.8.1) (0.18.1)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (5.1.3)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 72.9 MB/s
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.0)
# Collecting jupyterlab-widgets>=1.0.0; python_version >= "3.6"
#   Downloading jupyterlab_widgets-1.1.0-py3-none-any.whl (245 kB)
#      |████████████████████████████████| 245 kB 76.7 MB/s
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (7.32.0)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (6.1.12)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (4.7.1)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (6.3.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (4.8.0)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.1.3)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.17.2)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (3.0.28)
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit==1.8.1) (22.3.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (21.3.0)
# Requirement already satisfied: nbconvert==6.0.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.13.3)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.7.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.7.1)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (21.2.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.5.9)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.8.4)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.6.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.1.2)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (4.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.15.0)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (1.5.4)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (0.5.1)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1) (2.21)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=8f19b22427f885f6570001ab20733801d7ec2893985b376319d92cda4e701b77
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built blinker
# Installing collected packages: smmap, gitdb, gitpython, backports.zoneinfo, tzdata, pytz-deprecation-shim, tzlocal, watchdog, toml, validators, blinker, semver, widgetsnbextension, jupyterlab-widgets, ipywidgets, pydeck, pympler, streamlit
# Successfully installed backports.zoneinfo-0.2.1 blinker-1.4 gitdb-4.0.9 gitpython-3.1.27 ipywidgets-7.7.0 jupyterlab-widgets-1.1.0 pydeck-0.7.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 semver-2.13.0 smmap-5.0.0 streamlit-1.8.1 toml-0.10.2 tzdata-2022.1 tzlocal-4.2 validators-0.18.2 watchdog-2.1.7 widgetsnbextension-3.6.0
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install yfinance==0.1.70
# Out:
# Collecting yfinance==0.1.70
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pandas>=0.24.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from yfinance==0.1.70) (1.2.5)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.10.tar.gz (8.2 kB)
# Requirement already satisfied: lxml>=4.5.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from yfinance==0.1.70) (4.8.0)
# Requirement already satisfied: numpy>=1.15 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from yfinance==0.1.70) (1.21.5)
# Requirement already satisfied: requests>=2.26 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from yfinance==0.1.70) (2.27.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance==0.1.70) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance==0.1.70) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.26->yfinance==0.1.70) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests>=2.26->yfinance==0.1.70) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests>=2.26->yfinance==0.1.70) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.26->yfinance==0.1.70) (1.26.9)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance==0.1.70) (1.16.0)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8489 sha256=7b27a683c5a5ab5c98ecf0a2cefc841cd0b7606277fcfaff3ee013085a73e4e8
#   Stored in directory: /root/.cache/pip/wheels/34/ba/79/c0260c6f1a03f420ec7673eff9981778f293b9107974679e36
# Successfully built multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.10 yfinance-0.1.70
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install pycaret==2.3.10
# Out:
# Collecting pycaret==2.3.10
#   Downloading pycaret-2.3.10-py3-none-any.whl (320 kB)
#      |████████████████████████████████| 320 kB 32.5 MB/s
# Requirement already satisfied: textblob in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (0.17.1)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 76.3 MB/s
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 54.6 MB/s
# Requirement already satisfied: seaborn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (0.11.2)
# Requirement already satisfied: ipywidgets in /root/venv/lib/python3.7/site-packages (from pycaret==2.3.10) (7.7.0)
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 17.0 MB/s
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting pyod
#   Downloading pyod-0.9.9.tar.gz (116 kB)
#      |████████████████████████████████| 116 kB 80.4 MB/s
# Collecting numba<0.55
#   Downloading numba-0.54.1-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 61.9 MB/s
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 76.0 MB/s
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 54.3 MB/s
# Collecting cufflinks>=0.17.0
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      |████████████████████████████████| 81 kB 20.6 MB/s
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 54.5 MB/s
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 50.3 MB/s
# Requirement already satisfied: joblib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (1.1.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (3.5.1)
# Collecting mlflow
#   Downloading mlflow-1.25.1-py3-none-any.whl (16.8 MB)
#      |████████████████████████████████| 16.8 MB 53.8 MB/s
# Requirement already satisfied: plotly>=4.4.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (5.6.0)
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 55.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: nltk in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (3.7)
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 9.8 MB/s
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
#      |████████████████████████████████| 274 kB 80.2 MB/s
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 90.8 MB/s
# Requirement already satisfied: IPython in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pycaret==2.3.10) (7.32.0)
# Collecting pyyaml<6.0.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 69.9 MB/s
# Collecting wordcloud
#   Downloading wordcloud-1.8.1-cp37-cp37m-manylinux1_x86_64.whl (366 kB)
#      |████████████████████████████████| 366 kB 74.0 MB/s
# Collecting pandas-profiling>=2.8.0
#   Downloading pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
#      |████████████████████████████████| 261 kB 81.7 MB/s
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pycaret==2.3.10) (1.2.5)
# Requirement already satisfied: numpy>=1.16.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlxtend>=0.17.0->pycaret==2.3.10) (1.21.5)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from mlxtend>=0.17.0->pycaret==2.3.10) (47.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn==0.23.2->pycaret==2.3.10) (3.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (5.5.5)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /root/venv/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (3.6.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /root/venv/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (1.1.0)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->pycaret==2.3.10) (4.3.3)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.6.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 67.4 MB/s
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from umap-learn->pycaret==2.3.10) (4.63.0)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pyod->pycaret==2.3.10) (1.16.0)
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 25.3 MB/s
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp37-cp37m-manylinux2014_x86_64.whl (26.3 MB)
#      |████████████████████████████████| 26.3 MB 61.7 MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (1.0.6)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 61.2 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (2.27.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (0.9.0)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 74.1 MB/s
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (3.0.6)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from spacy<2.4.0->pycaret==2.3.10) (0.7.7)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from gensim<4.0.0->pycaret==2.3.10) (5.2.1)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/site-packages (from lightgbm>=2.3.1->pycaret==2.3.10) (0.37.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (4.31.2)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->pycaret==2.3.10) (0.11.0)
# Collecting cloudpickle
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (8.0.4)
# Collecting gunicorn; platform_system != "Windows"
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 17.5 MB/s
# Requirement already satisfied: entrypoints in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (0.4)
# Requirement already satisfied: gitpython>=2.1.0 in /root/venv/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (3.1.27)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (4.11.3)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 73.1 MB/s
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 73.7 MB/s
# Requirement already satisfied: sqlparse>=0.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (0.4.2)
# Collecting Flask
#   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 11.0 MB/s
# Requirement already satisfied: pytz in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (2022.1)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.16.6.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Requirement already satisfied: protobuf>=3.7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (3.19.4)
# Requirement already satisfied: sqlalchemy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from mlflow->pycaret==2.3.10) (1.4.32)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.20.1-py3-none-any.whl (18 kB)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly>=4.4.1->pycaret==2.3.10) (8.0.1)
# Collecting numexpr
#   Downloading numexpr-2.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (379 kB)
#      |████████████████████████████████| 379 kB 84.7 MB/s
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pyLDAvis->pycaret==2.3.10) (3.0.3)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: future in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pyLDAvis->pycaret==2.3.10) (0.18.2)
# Requirement already satisfied: regex>=2021.8.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from nltk->pycaret==2.3.10) (2022.3.15)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (2.11.2)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.17.2)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (3.0.28)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from IPython->pycaret==2.3.10) (0.7.5)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Collecting tangled-up-in-unicode==0.1.0
#   Downloading tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 59.0 MB/s
# Collecting markupsafe~=2.0.1
#   Downloading MarkupSafe-2.0.1-cp37-cp37m-manylinux2010_x86_64.whl (31 kB)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (690 kB)
#      |████████████████████████████████| 690 kB 91.7 MB/s
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 22.6 MB/s
# Requirement already satisfied: pydantic>=1.8.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas-profiling>=2.8.0->pycaret==2.3.10) (1.8.2)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Requirement already satisfied: tornado>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.3.10) (6.1)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==2.3.10) (6.1.12)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret==2.3.10) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->pycaret==2.3.10) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (6.3.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 70.5 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0->pycaret==2.3.10) (1.26.9)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->pycaret==2.3.10) (4.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /root/venv/lib/python3.7/site-packages (from gitpython>=2.1.0->mlflow->pycaret==2.3.10) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret==2.3.10) (3.7.0)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 6.2 MB/s
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 15.2 MB/s
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /shared-libs/python3.7/py/lib/python3.7/site-packages (from alembic->mlflow->pycaret==2.3.10) (5.4.0)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: Werkzeug>=2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from Flask->mlflow->pycaret==2.3.10) (2.0.3)
# Requirement already satisfied: pyjwt>=1.7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret==2.3.10) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret==2.3.10) (3.2.0)
# Requirement already satisfied: tabulate>=0.7.7 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from databricks-cli>=0.8.7->mlflow->pycaret==2.3.10) (0.8.9)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /shared-libs/python3.7/py/lib/python3.7/site-packages (from sqlalchemy->mlflow->pycaret==2.3.10) (1.1.2)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prometheus-flask-exporter->mlflow->pycaret==2.3.10) (0.13.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->IPython->pycaret==2.3.10) (0.7.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->IPython->pycaret==2.3.10) (0.7.1)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret==2.3.10) (0.2.5)
# Collecting networkx>=2.4
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 36.5 MB/s
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret==2.3.10) (21.4.0)
# Collecting imagehash; extra == "type_image_path"
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      |████████████████████████████████| 812 kB 69.6 MB/s
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->pycaret==2.3.10) (22.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret==2.3.10) (0.18.1)
# Requirement already satisfied: nbconvert==6.0.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.8.0)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.13.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /root/venv/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->pycaret==2.3.10) (5.0.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 65.5 MB/s
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.1.2)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.5.9)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.8.4)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.5.0)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (21.2.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (0.5.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert==6.0.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.5.4)
# Requirement already satisfied: cffi>=1.0.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (1.15.0)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pycaret==2.3.10) (2.21)
# Building wheels for collected packages: umap-learn, pyod, cufflinks, pyLDAvis, pynndescent, databricks-cli, sklearn, htmlmin, imagehash
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82819 sha256=52d7917d297a38b220dbd2645618abbc3b9275a052fc73b9dac839f468f4a39f
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-0.9.9-py3-none-any.whl size=139313 sha256=3287edfb73ac9c547f36be33129853a385e6f40830237e59b854f5c040f21acd
#   Stored in directory: /root/.cache/pip/wheels/68/32/f0/0dc3050775e77b6661a116b70817b02b4305fa253269d6d998
#   Building wheel for cufflinks (setup.py) ... done
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67920 sha256=c6f827010dfcb10b465575a3f6a3af14c9b1ab82cbb244f3ac471b4283f180df
#   Stored in directory: /root/.cache/pip/wheels/e1/27/13/3fe67fa7ea7be444b831d117220b3b586b872c9acd4df480d0
#   Building wheel for pyLDAvis (PEP 517) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136897 sha256=51931b1a3d3863f98e46c28e7e172f05ceade22cb612f4927d55f6f411be4efe
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.6-py3-none-any.whl size=53930 sha256=7af58b44b94f3e5f75562ad6e1fc3c1134e713ef9bd7a82db25d80b17ed4dc5d
#   Stored in directory: /root/.cache/pip/wheels/03/f1/56/f80d72741e400345b5a5b50ec3d929aca581bf45e0225d5c50
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.6-py3-none-any.whl size=112628 sha256=367444221309bd21d08b013d6619213329113b8ef3ee08219b7ae626f65a3ebf
#   Stored in directory: /root/.cache/pip/wheels/96/c1/f8/d75a22e789ab6a4dff11f18338c3af4360189aa371295cc934
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1317 sha256=6ae4416c832826d39e3f99f896e100f8404312f359db49cddb1b575ec68d47fa
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27085 sha256=3bfc84bf477724407bc9e6b3aac2c9b71177cd2234e12b4be79f4a60e980f810
#   Stored in directory: /root/.cache/pip/wheels/70/e1/52/5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655
#   Building wheel for imagehash (setup.py) ... done
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295197 sha256=1e6f0c06b68cf03b2a477de1441e898ac398fe4382ac57d933f8e9581bfb3b98
#   Stored in directory: /root/.cache/pip/wheels/4c/d5/59/5e3e297533ddb09407769762985d134135064c6831e29a914e
# Successfully built umap-learn pyod cufflinks pyLDAvis pynndescent databricks-cli sklearn htmlmin imagehash
# ERROR: numba 0.54.1 has requirement numpy<1.21,>=1.17, but you'll have numpy 1.21.5 which is incompatible.
# ERROR: yellowbrick 1.4 has requirement scikit-learn>=1.0.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# ERROR: pandas-profiling 3.1.0 has requirement joblib~=1.0.1, but you'll have joblib 1.1.0 which is incompatible.
# Installing collected packages: scipy, scikit-learn, mlxtend, llvmlite, numba, pynndescent, umap-learn, scikit-plot, patsy, statsmodels, pyod, plac, srsly, catalogue, thinc, spacy, gensim, colorlover, cufflinks, lightgbm, cloudpickle, gunicorn, websocket-client, docker, markupsafe, Mako, alembic, itsdangerous, Flask, databricks-cli, pyyaml, prometheus-flask-exporter, querystring-parser, mlflow, kmodes, numexpr, sklearn, funcy, pyLDAvis, Boruta, yellowbrick, imbalanced-learn, wordcloud, multimethod, tangled-up-in-unicode, missingno, phik, networkx, PyWavelets, imagehash, visions, htmlmin, pandas-profiling, pycaret
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Not uninstalling scipy at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'scipy'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Not uninstalling scikit-learn at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
#     Not uninstalling srsly at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'srsly'. No files were found to uninstall.
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.7
#     Not uninstalling catalogue at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'catalogue'. No files were found to uninstall.
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.15
#     Not uninstalling thinc at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'thinc'. No files were found to uninstall.
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.3
#     Not uninstalling spacy at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'spacy'. No files were found to uninstall.
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.1
#     Not uninstalling markupsafe at /shared-libs/python3.7/py-core/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Not uninstalling pyyaml at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'PyYAML'. No files were found to uninstall.
# Successfully installed Boruta-0.3 Flask-2.1.1 Mako-1.2.0 PyWavelets-1.3.0 alembic-1.7.7 catalogue-1.0.0 cloudpickle-2.0.0 colorlover-0.3.0 cufflinks-0.17.3 databricks-cli-0.16.6 docker-5.0.3 funcy-1.17 gensim-3.8.3 gunicorn-20.1.0 htmlmin-0.1.12 imagehash-4.2.1 imbalanced-learn-0.7.0 itsdangerous-2.1.2 kmodes-0.12.1 lightgbm-3.3.2 llvmlite-0.37.0 markupsafe-2.0.1 missingno-0.5.1 mlflow-1.25.1 mlxtend-0.19.0 multimethod-1.8 networkx-2.6.3 numba-0.54.1 numexpr-2.8.1 pandas-profiling-3.1.0 patsy-0.5.2 phik-0.12.2 plac-1.1.3 prometheus-flask-exporter-0.20.1 pyLDAvis-3.3.1 pycaret-2.3.10 pynndescent-0.5.6 pyod-0.9.9 pyyaml-5.4.1 querystring-parser-1.2.4 scikit-learn-0.23.2 scikit-plot-0.3.7 scipy-1.5.4 sklearn-0.0 spacy-2.3.7 srsly-1.0.5 statsmodels-0.13.2 tangled-up-in-unicode-0.1.0 thinc-7.4.5 umap-learn-0.5.3 visions-0.7.4 websocket-client-1.3.2 wordcloud-1.8.1 yellowbrick-1.4
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install numpy==1.18.5
# Out:
# Collecting numpy==1.18.5
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 20.8 MB/s
# ERROR: yellowbrick 1.4 has requirement scikit-learn>=1.0.0, but you'll have scikit-learn 0.23.2 which is incompatible.
# ERROR: pyldavis 3.3.1 has requirement numpy>=1.20.0, but you'll have numpy 1.18.5 which is incompatible.
# ERROR: pandas-profiling 3.1.0 has requirement joblib~=1.0.1, but you'll have joblib 1.1.0 which is incompatible.
# ERROR: pandas-profiling 3.1.0 has requirement markupsafe~=2.0.1, but you'll have markupsafe 2.1.1 which is incompatible.
# ERROR: tensorflow 2.8.0 has requirement numpy>=1.20, but you'll have numpy 1.18.5 which is incompatible.
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Not uninstalling numpy at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'numpy'. No files were found to uninstall.
# Successfully installed numpy-1.18.5
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import streamlit as st
import pandas as pd
import datetime
import numpy as np
from datetime import timedelta
from datetime import datetime
import yfinance as yf
import plotly.graph_objects as go
from pycaret.regression import *

# %%
stock_list = [
    'ONGC.NS', 'UPL.NS', 'ITC.NS', 'SUNPHARMA.NS', 'IOC.NS', 'JSWSTEEL.NS',
    'SBIN.NS', 'SHREECEM.NS', 'HINDUNILVR.NS', 'NTPC.NS', 'HINDALCO.NS',
    'LT.NS', 'BAJFINANCE.NS', 'DIVISLAB.NS', 'TATACONSUM.NS', 'HDFCLIFE.NS',
    'M&M.NS', 'INFY.NS', 'GRASIM.NS', 'WIPRO.NS', 'COALINDIA.NS',
    'BRITANNIA.NS', 'INDUSINDBK.NS', 'BHARTIARTL.NS', 'SBILIFE.NS',
    'ICICIBANK.NS', 'TATASTEEL.NS', 'RELIANCE.NS', 'HCLTECH.NS',
    'BAJAJ-AUTO.NS', 'BPCL.NS', 'TCS.NS', 'NESTLEIND.NS', 'ADANIPORTS.NS',
    'AXISBANK.NS', 'ULTRACEMCO.NS', 'CIPLA.NS', 'TITAN.NS', 'HEROMOTOCO.NS',
    'KOTAKBANK.NS', 'BAJAJFINSV.NS', 'POWERGRID.NS', 'ASIANPAINT.NS',
    'EICHERMOT.NS', 'TATAMOTORS.NS', 'DRREDDY.NS', 'HDFCBANK.NS', 'HDFC.NS',
    'MARUTI.NS'
]

# %%
column_names = ["Date", "Close", "stock_name"]

df = pd.DataFrame(columns = column_names)
df['Date'] = pd.to_datetime(df['Date'])
df["Close"] = df["Close"]
df.head()
# Out:
# Empty DataFrame
# Columns: [Date, Close, stock_name]
# Index: []

# %%
end = datetime.today().date()
start = end - timedelta(days=1456)

for i in stock_list:
    stock = yf.download(i,start= start, end=end)
    stock = stock.round({'Close': 3})
    stock = stock.reset_index()[["Date","Close"]]
    stock['stock_name'] = i
    df = df.append(stock)
# Out:
# 2022-04-19 04:11:17.534 INFO    numexpr.utils: NumExpr defaulting to 4 threads.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df['Close'] = df['Close'].ffill()

# %%
data = df.copy()
data['month'] = [i.month for i in data['Date']]
data['year'] = [i.year for i in data['Date']]
data['day_of_week'] = [i.dayofweek for i in data['Date']]
data['day_of_year'] = [i.dayofyear for i in data['Date']]

data.set_index('Date', inplace=True)

# %%
data.head()
# Out:
#              Close stock_name  month  year  day_of_week  day_of_year
# Date
# 2018-04-24  182.65    ONGC.NS      4  2018            1          114
# 2018-04-25  179.45    ONGC.NS      4  2018            2          115
# 2018-04-26  180.80    ONGC.NS      4  2018            3          116
# 2018-04-27  180.70    ONGC.NS      4  2018            4          117
# 2018-04-30  180.55    ONGC.NS      4  2018            0          120

# %%
all_ts = data['stock_name'].unique()
all_results = []
final_model = {}

for i in all_ts:
    df_subset = data[data['stock_name'] == i]
    # initialize setup from pycaret.regression
    s = setup(df_subset, target = 'Close', train_size = 0.95, transform_target = True, data_split_shuffle = False,
              fold_strategy = 'timeseries', fold = 5, ignore_features = ['stock_name'], numeric_features = ['day_of_year', 'year','month', 'day_of_week'],
               silent = True, verbose = False, session_id = 2022)
    # compare all models and select best one based on MAE
    best_model = compare_models(sort = 'MAE', verbose=True)
    
    # capture the compare result grid and store best model in list
    p = pull().iloc[0:1]
    p['stock_name'] = str(i)
    all_results.append(p)
    
    # finalize model i.e. fit on entire data including test set
    f = finalize_model(best_model)
    
    # attach final model to a dictionary
    final_model[i] = f
    
    # save transformation pipeline and model as pickle file 
    save_model(f, model_name='/work/NIFTY50-Stock-Analysis/models/' + str(i), verbose=False)
# Out:
# <style  type="text/css" >
#     #T_4a1b1_ th {
#           text-align: left;
#     }#T_4a1b1_row0_col0,#T_4a1b1_row0_col3,#T_4a1b1_row0_col4,#T_4a1b1_row1_col0,#T_4a1b1_row1_col1,#T_4a1b1_row1_col2,#T_4a1b1_row1_col5,#T_4a1b1_row2_col0,#T_4a1b1_row2_col1,#T_4a1b1_row2_col2,#T_4a1b1_row2_col3,#T_4a1b1_row2_col4,#T_4a1b1_row2_col5,#T_4a1b1_row2_col6,#T_4a1b1_row3_col0,#T_4a1b1_row3_col1,#T_4a1b1_row3_col2,#T_4a1b1_row3_col3,#T_4a1b1_row3_col4,#T_4a1b1_row3_col5,#T_4a1b1_row3_col6,#T_4a1b1_row4_col0,#T_4a1b1_row4_col1,#T_4a1b1_row4_col2,#T_4a1b1_row4_col3,#T_4a1b1_row4_col4,#T_4a1b1_row4_col5,#T_4a1b1_row4_col6,#T_4a1b1_row5_col0,#T_4a1b1_row5_col1,#T_4a1b1_row5_col2,#T_4a1b1_row5_col3,#T_4a1b1_row5_col4,#T_4a1b1_row5_col5,#T_4a1b1_row5_col6,#T_4a1b1_row6_col0,#T_4a1b1_row6_col1,#T_4a1b1_row6_col2,#T_4a1b1_row6_col3,#T_4a1b1_row6_col4,#T_4a1b1_row6_col5,#T_4a1b1_row6_col6,#T_4a1b1_row7_col0,#T_4a1b1_row7_col1,#T_4a1b1_row7_col2,#T_4a1b1_row7_col3,#T_4a1b1_row7_col4,#T_4a1b1_row7_col5,#T_4a1b1_row7_col6,#T_4a1b1_row8_col0,#T_4a1b1_row8_col1,#T_4a1b1_row8_col2,#T_4a1b1_row8_col3,#T_4a1b1_row8_col4,#T_4a1b1_row8_col5,#T_4a1b1_row8_col6,#T_4a1b1_row9_col0,#T_4a1b1_row9_col1,#T_4a1b1_row9_col2,#T_4a1b1_row9_col3,#T_4a1b1_row9_col4,#T_4a1b1_row9_col5,#T_4a1b1_row9_col6,#T_4a1b1_row10_col0,#T_4a1b1_row10_col1,#T_4a1b1_row10_col2,#T_4a1b1_row10_col3,#T_4a1b1_row10_col4,#T_4a1b1_row10_col5,#T_4a1b1_row10_col6,#T_4a1b1_row11_col0,#T_4a1b1_row11_col1,#T_4a1b1_row11_col2,#T_4a1b1_row11_col3,#T_4a1b1_row11_col4,#T_4a1b1_row11_col5,#T_4a1b1_row11_col6,#T_4a1b1_row12_col0,#T_4a1b1_row12_col1,#T_4a1b1_row12_col2,#T_4a1b1_row12_col3,#T_4a1b1_row12_col4,#T_4a1b1_row12_col5,#T_4a1b1_row12_col6,#T_4a1b1_row13_col0,#T_4a1b1_row13_col1,#T_4a1b1_row13_col2,#T_4a1b1_row13_col3,#T_4a1b1_row13_col4,#T_4a1b1_row13_col5,#T_4a1b1_row13_col6,#T_4a1b1_row14_col0,#T_4a1b1_row14_col1,#T_4a1b1_row14_col2,#T_4a1b1_row14_col3,#T_4a1b1_row14_col4,#T_4a1b1_row14_col5,#T_4a1b1_row14_col6,#T_4a1b1_row15_col0,#T_4a1b1_row15_col1,#T_4a1b1_row15_col2,#T_4a1b1_row15_col3,#T_4a1b1_row15_col4,#T_4a1b1_row15_col5,#T_4a1b1_row15_col6,#T_4a1b1_row16_col0,#T_4a1b1_row16_col1,#T_4a1b1_row16_col2,#T_4a1b1_row16_col3,#T_4a1b1_row16_col4,#T_4a1b1_row16_col5,#T_4a1b1_row16_col6,#T_4a1b1_row17_col0,#T_4a1b1_row17_col1,#T_4a1b1_row17_col2,#T_4a1b1_row17_col3,#T_4a1b1_row17_col4,#T_4a1b1_row17_col5,#T_4a1b1_row17_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_4a1b1_row0_col1,#T_4a1b1_row0_col2,#T_4a1b1_row0_col5,#T_4a1b1_row0_col6,#T_4a1b1_row1_col3,#T_4a1b1_row1_col4,#T_4a1b1_row1_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_4a1b1_row0_col7,#T_4a1b1_row1_col7,#T_4a1b1_row2_col7,#T_4a1b1_row3_col7,#T_4a1b1_row4_col7,#T_4a1b1_row5_col7,#T_4a1b1_row6_col7,#T_4a1b1_row8_col7,#T_4a1b1_row9_col7,#T_4a1b1_row11_col7,#T_4a1b1_row12_col7,#T_4a1b1_row16_col7,#T_4a1b1_row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_4a1b1_row7_col7,#T_4a1b1_row10_col7,#T_4a1b1_row13_col7,#T_4a1b1_row14_col7,#T_4a1b1_row15_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_4a1b1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a1b1_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#                         <td id="T_4a1b1_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_4a1b1_row0_col1" class="data row0 col1" >744.0253</td>
#                         <td id="T_4a1b1_row0_col2" class="data row0 col2" >890918.6945</td>
#                         <td id="T_4a1b1_row0_col3" class="data row0 col3" >829.2949</td>
#                         <td id="T_4a1b1_row0_col4" class="data row0 col4" >-11.8494</td>
#                         <td id="T_4a1b1_row0_col5" class="data row0 col5" >0.2334</td>
#                         <td id="T_4a1b1_row0_col6" class="data row0 col6" >0.1829</td>
#                         <td id="T_4a1b1_row0_col7" class="data row0 col7" >0.0560</td>
#             </tr>
#             <tr>
#                         <th id="T_4a1b1_level0_row1" class="row_heading level0 row1" >ada</th>
#                         <td id="T_4a1b1_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#                         <td id="T_4a1b1_row1_col1" class="data row1 col1" >745.7322</td>
#                         <td id="T_4a1b1_row1_col2" class="data row1 col2" >945002.1184</td>
#                         <td id="T_4a1b1_row1_col3" class="data row1 col3" >819.9391</td>
#                         <td id="T_4a1b1_row1_col4" class="data row1 col4" >-10.9856</td>
#                         <td id="T_4a1b1_row1_col5" class="data row1 col5" >0.2343</td>
#                         <td id="T_4a1b1_row1_col6" class="data row1 col6" >0.1829</td>
#                         <td id="T_4a1b1_row1_col7" class="data row1 col7" >0.0860</td>
#             </tr>
#             <tr>
#                         <th id="T_4a1b1_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_4a1b1_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_4a1b1_row2_col1" class="data row2 col1" >777.6632</td>
#                         <td id="T_4a1b1_row2_col2" class="data row2 col2" >1024670.9405</td>
#                         <td id="T_4a1b1_row2_col3" class="data row2 col3" >860.8577</td>
#                         <td id="T_4a1b1_row2_col4" class="data row2 col4" >-11.2235</td>
#                         <td id="T_4a1b1_row2_col5" class="data row2 col5" >0.2460</td>
#                         <td id="T_4a1b1_row2_col6" class="data row2 col6" >0.1904</td>
#                         <td id="T_4a1b1_row2_col7" class="data row2 col7" >0.2920</td>
#             </tr>
#             <tr>
#                         <th id="T_4a1b1_level0_row3" class="row_heading level0 row3" >omp</th>
#                         <td id="T_4a1b1_row3_col0" class="data row3 col0" >Orthogonal Matching Pursuit</td>
#                         <td id="T_4a1b1_row3_col1" class="data row3 col1" >787.6842</td>
#                         <td id="T_4a1b1_row3_col2" class="data row3 col2" >1112593.7685</td>
#                         <td id="T_4a1b1_row3_col3" class="data row3 col3" >951.3371</td>
#                         <td id="T_4a1b1_row3_col4" class="data row3 col4" >-17.9779</td>
#                         <td id="T_4a1b1_row3_col5" class="data row3 col5" >0.2399</td>
#                         <td id="T_4a1b1_row3_col6" class="data row3 col6" >0.1949</td>
#                         <td id="T_4a1b1_row3_col7" class="data row3 col7" >0.0400</td>
#             </tr>
#             <tr>
#                         <th id="T_4a1b1_level0_row4" class="row_heading level0 row4" >dt</th>
#                         <td id="T_4a1b1_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#                         <td id="T_4a1b1_row4_col1" class="data row4 col1" >793.4946</td>
#                         <td id="T_4a1b1_row4_col2" class="data row4 col2" >1053172.5630</td>
#                         <td id="T_4a1b1_row4_col3" class="data row4 col3" >876.2518</td>
#                         <td id="T_4a1b1_row4_col4" class="data row4 col4" >-11.3151</td>
#                         <td id="T_4a1b1_row4_col5" class="data row4 col5" >0.2504</td>
#                         <td id="T_
# 2022-04-19 04:30:19.545 INFO    logs: create_model_container: 18
# 2022-04-19 04:30:19.546 INFO    logs: master_model_container: 18
# 2022-04-19 04:30:19.547 INFO    logs: display_container: 2
# 2022-04-19 04:30:19.551 INFO    logs: PowerTransformedTargetRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2...
#                                                         importance_type='split',
#                                                         learning_rate=0.1,
#                                                         max_depth=-1,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=100,
#                                                         n_jobs=-1,
#                                                         num_leaves=31,
#                                                         objective=None,
#                                                         random_state=2022,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent='warn',
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0)
# 2022-04-19 04:30:19.552 INFO    logs: compare_models() succesfully completed......................................
# 2022-04-19 04:30:19.556 INFO    logs: Initializing finalize_model()
# 2022-04-19 04:30:19.557 INFO    logs: finalize_model(estimator=PowerTransformedTargetRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2...
#                                                         importance_type='split',
#                                                         learning_rate=0.1,
#                                                         max_depth=-1,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=100,
#                                                         n_jobs=-1,
#                                                         num_leaves=31,
#                                                         objective=None,
#                                                         random_state=2022,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent='warn',
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0), fit_kwargs=None, groups=None, model_only=True, display=None, experiment_custom_tags=None, return_train_score=False)
# 2022-04-19 04:30:19.560 INFO    logs: Finalizing PowerTransformedTargetRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2...
#                                                         importance_type='split',
#                                                         learning_rate=0.1,
#                                                         max_depth=-1,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=100,
#                                                         n_jobs=-1,
#                                                         num_leaves=31,
#                                                         objective=None,
#                                                         random_state=2022,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent='warn',
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0)
# 2022-04-19 04:30:19.563 INFO    logs: Initializing create_model()
# 2022-04-19 04:30:19.565 INFO    logs: create_model(estimator=PowerTransformedTargetRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2...
#                                                         importance_type='split',
#                                                         learning_rate=0.1,
#                                                         max_depth=-1,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=100,
#                                                         n_jobs=-1,
#                                                         num_leaves=31,
#                                                         objective=None,
#                                                         random_state=2022,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent='warn',
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0), fold=None, round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=True, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=False, probability_threshold=None, display=None, return_train_score=False, kwargs={})
# 2022-04-19 04:30:19.566 INFO    logs: Checking exceptions
# 2022-04-19 04:30:19.567 INFO    logs: Importing libraries
# 2022-04-19 04:30:19.567 INFO    logs: Copying training dataset
# 2022-04-19 04:30:19.569 INFO    logs: Defining folds
# 2022-04-19 04:30:19.570 INFO    logs: Declaring metric variables
# 2022-04-19 04:30:19.571 INFO    logs: Importing untrained model
# 2022-04-19 04:30:19.572 INFO    logs: Declaring custom model
# 2022-04-19 04:30:19.575 INFO    logs: Light Gradient Boosting Machine Imported succesfully
# 2022-04-19 04:30:19.576 INFO    logs: Starting cross validation
# 2022-04-19 04:30:19.578 INFO    logs: Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=5), n_jobs=-1
# 2022-04-19 04:30:19.890 INFO    logs: Calculating mean and std
# 2022-04-19 04:30:19.892 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:30:19.898 INFO    logs: Finalizing model
# 2022-04-19 04:30:20.069 INFO    logs: create_model_container: 18
# 2022-04-19 04:30:20.070 INFO    logs: master_model_container: 18
# 2022-04-19 04:30:20.071 INFO    logs: display_container: 3
# 2022-04-19 04:30:20.076 INFO    logs: PowerTransformedTargetRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2...
#                                                         importance_type='split',
#                                                         learning_rate=0.1,
#                                                         max_depth=-1,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=100,
#                                                         n_jobs=-1,
#                                                         num_leaves=31,
#                                                         objective=None,
#                                                         random_state=2022,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent='warn',
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0)
# 2022-04-19 04:30:20.085 INFO    logs: create_model() succesfully completed......................................
# 2022-04-19 04:30:20.251 INFO    logs: create_model_container: 18
# 2022-04-19 04:30:20.252 INFO    logs: master_model_container: 18
# 2022-04-19 04:30:20.253 INFO    logs: display_container: 2
# 2022-04-19 04:30:20.257 INFO    logs: PowerTransformedTargetRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2...
#                                                         importance_type='split',
#                                                         learning_rate=0.1,
#                                                         max_depth=-1,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=100,
#                                                         n_jobs=-1,
#                                                         num_leaves=31,
#                                                         objective=None,
#                                                         random_state=2022,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent='warn',
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0)
# 2022-04-19 04:30:20.259 INFO    logs: finalize_model() succesfully completed......................................
# 2022-04-19 04:30:20.436 INFO    logs: Initializing save_model()
# 2022-04-19 04:30:20.437 INFO    logs: save_model(model=PowerTransformedTargetRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2...
#                                                         importance_type='split',
#                                                         learning_rate=0.1,
#                                                         max_depth=-1,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=100,
#                                                         n_jobs=-1,
#                                                         num_leaves=31,
#                                                         objective=None,
#                                                         random_state=2022,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent='warn',
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0), model_name=/work/NIFTY50-Stock-Analysis/models/DRREDDY.NS, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False,
#                                       features_todrop=['stock_name'],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=['day_of_year', 'year',
#                                                           'month',
#                                                           'day_of_week'],
#                                       target='Close', time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_catego...
#                 ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='Close')),
#                 ('fix_perfect', Remove_100(target='Close')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False), verbose=False, kwargs={})
# 2022-04-19 04:30:20.441 INFO    logs: Adding model into prep_pipe
# 2022-04-19 04:30:20.475 INFO    logs: /work/NIFTY50-Stock-Analysis/models/DRREDDY.NS.pkl saved in current working directory
# 2022-04-19 04:30:20.492 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False,
#                                       features_todrop=['stock_name'],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=['day_of_year', 'year',
#                                                           'month',
#                                                           'day_of_week'],
#                                       target='Close', time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_catego...
#                                                                          learning_rate=0.1,
#                                                                          max_depth=-1,
#                                                                          min_child_samples=20,
#                                                                          min_child_weight=0.001,
#                                                                          min_split_gain=0.0,
#                                                                          n_estimators=100,
#                                                                          n_jobs=-1,
#                                                                          num_leaves=31,
#                                                                          objective=None,
#                                                                          random_state=2022,
#                                                                          reg_alpha=0.0,
#                                                                          reg_lambda=0.0,
#                                                                          silent='warn',
#                                                                          subsample=1.0,
#                                                                          subsample_for_bin=200000,
#                                                                          subsample_freq=0),
#                                                  silent='warn', subsample=1.0,
#                                                  subsample_for_bin=200000,
#                                                  subsample_freq=0)]],
#          verbose=False)
# 2022-04-19 04:30:20.495 INFO    logs: save_model() successfully completed......................................
# 2022-04-19 04:30:20.653 INFO    logs: PyCaret Supervised Module
# 2022-04-19 04:30:20.654 INFO    logs: ML Usecase: regression
# 2022-04-19 04:30:20.655 INFO    logs: version 2.3.10
# 2022-04-19 04:30:20.655 INFO    logs: Initializing setup()
# 2022-04-19 04:30:20.656 INFO    logs: setup(target=Close, ml_usecase=regression, available_plots={'parameter': 'Hyperparameters', 'residuals': 'Residuals', 'error': 'Prediction Error', 'cooks': 'Cooks Distance', 'rfe': 'Feature Selection', 'learning': 'Learning Curve', 'manifold': 'Manifold Learning', 'vc': 'Validation Curve', 'feature': 'Feature Importance', 'feature_all': 'Feature Importance (All)', 'tree': 'Decision Tree', 'residuals_interactive': 'Interactive Residuals'}, train_size=0.95, test_data=None, preprocess=True, imputation_type=simple, iterative_imputation_iters=5, categorical_features=None, categorical_imputation=constant, categorical_iterative_imputer=lightgbm, ordinal_features=None, high_cardinality_features=None, high_cardinality_method=frequency, numeric_features=['day_of_year', 'year', 'month', 'day_of_week'], numeric_imputation=mean, numeric_iterative_imputer=lightgbm, date_features=None, ignore_features=['stock_name'], normalize=False, normalize_method=zscore, transformation=False, transformation_method=yeo-johnson, handle_unknown_categorical=True, unknown_categorical_method=least_frequent, pca=False, pca_method=linear, pca_components=None, ignore_low_variance=False, combine_rare_levels=False, rare_level_threshold=0.1, bin_numeric_features=None, remove_outliers=False, outliers_threshold=0.05, remove_multicollinearity=False, multicollinearity_threshold=0.9, remove_perfect_collinearity=True, create_clusters=False, cluster_iter=20, polynomial_features=False, polynomial_degree=2, trigonometry_features=False, polynomial_threshold=0.1, group_features=None, group_names=None, feature_selection=False, feature_selection_threshold=0.8, feature_selection_method=classic, feature_interaction=False, feature_ratio=False, interaction_threshold=0.01, fix_imbalance=False, fix_imbalance_method=None, transform_target=True, transform_target_method=box-cox, data_split_shuffle=False, data_split_stratify=False, fold_strategy=timeseries, fold=5, fold_shuffle=False, fold_groups=None, n_jobs=-1, use_gpu=False, custom_pipeline=None, html=True, session_id=2022, log_experiment=False, experiment_name=None, experiment_custom_tags=None, log_plots=False, log_profile=False, log_data=False, silent=True, verbose=False, profile=False, profile_kwargs=None, display=None)
# 2022-04-19 04:30:20.656 INFO    logs: Checking environment
# 2022-04-19 04:30:20.657 INFO    logs: python_version: 3.7.12
# 2022-04-19 04:30:20.657 INFO    logs: python_build: ('default', 'Oct 12 2021 03:36:26')
# 2022-04-19 04:30:20.658 INFO    logs: machine: x86_64
# 2022-04-19 04:30:20.659 INFO    logs: platform: Linux-5.4.95-42.163.amzn2.x86_64-x86_64-with-debian-10.11
# 2022-04-19 04:30:20.661 WARNING logs: cannot find psutil installation. memory not traceable. Install psutil using pip to enable memory logging.
# 2022-04-19 04:30:20.662 INFO    logs: Checking libraries
# 2022-04-19 04:30:20.663 INFO    logs: pd==1.2.5
# 2022-04-19 04:30:20.664 INFO    logs: numpy==1.21.5
# 2022-04-19 04:30:20.664 INFO    logs: sklearn==0.23.2
# 2022-04-19 04:30:20.665 INFO    logs: lightgbm==3.3.2
# 2022-04-19 04:30:20.668 WARNING logs: catboost not found
# 2022-04-19 04:30:20.669 WARNING logs: xgboost not found
# 2022-04-19 04:30:20.670 INFO    logs: mlflow==1.25.1
# 2022-04-19 04:30:20.671 INFO    logs: Checking Exceptions
# 2022-04-19 04:30:20.671 INFO    logs: Declaring global variables
# 2022-04-19 04:30:20.672 INFO    logs: USI: 78ea
# 2022-04-19 04:30:20.673 INFO    logs: pycaret_globals: {'dashboard_logger', 'fold_groups_param', 'data_before_preprocess', 'imputation_regressor', '_all_models_internal', 'gpu_param', 'X_train', '_all_metrics', 'fix_imbalance_param', '_ml_usecase', 'create_model_container', 'target_param', 'X_test', 'USI', 'transform_target_param', 'y', '_available_plots', 'y_test', 'display_container', 'master_model_container', 'fold_generator', 'experiment__', '_internal_pipeline', 'pycaret_globals', '_all_models', 'X', 'fold_shuffle_param', 'fix_imbalance_method_param', 'fold_groups_param_full', 'stratify_param', 'seed', 'log_plots_param', 'n_jobs_param', 'iterative_imputation_iters_param', 'imputation_classifier', 'html_param', '_gpu_n_jobs_param', 'y_train', 'prep_pipe', 'exp_name_log', 'transform_target_method_param', 'fold_param', 'logging_param'}
# 2022-04-19 04:30:20.673 INFO    logs: Preparing display monitor
# 2022-04-19 04:30:20.674 INFO    logs: Importing libraries
# 2022-04-19 04:30:20.675 INFO    logs: Copying data for preprocessing
# 2022-04-19 04:30:20.676 INFO    logs: Declaring preprocessing parameters
# 2022-04-19 04:30:20.678 INFO    logs: Creating preprocessing pipeline
# 2022-04-19 04:30:20.685 INFO    logs: Preprocessing pipeline created successfully
# 2022-04-19 04:30:20.686 ERROR   logs: (Process Exit): setup has been interupted with user command 'quit'. setup must rerun.
# 2022-04-19 04:30:20.687 INFO    logs: Creating global containers
# 2022-04-19 04:30:20.688 INFO    logs: Internal pipeline: Pipeline(memory=None, steps=[('empty_step', 'passthrough')], verbose=False)
# 2022-04-19 04:30:20.905 WARNING logs: Couldn't import xgboost.XGBRegressor
# 2022-04-19 04:30:20.906 WARNING logs: Couldn't import catboost.CatBoostRegressor
# 2022-04-19 04:30:21.028 WARNING logs: Couldn't import xgboost.XGBRegressor
# 2022-04-19 04:30:21.029 WARNING logs: Couldn't import catboost.CatBoostRegressor
# 2022-04-19 04:30:21.031 INFO    logs: Creating grid variables
# 2022-04-19 04:30:21.035 INFO    logs: create_model_container: 0
# 2022-04-19 04:30:21.036 INFO    logs: master_model_container: 0
# 2022-04-19 04:30:21.036 INFO    logs: display_container: 1
# 2022-04-19 04:30:21.042 INFO    logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=False,
#                                       features_todrop=['stock_name'],
#                                       id_columns=[], ml_usecase='regression',
#                                       numerical_features=['day_of_year', 'year',
#                                                           'month',
#                                                           'day_of_week'],
#                                       target='Close', time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_catego...
#                 ('scaling', 'passthrough'), ('P_transform', 'passthrough'),
#                 ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                 ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='Close')),
#                 ('fix_perfect', Remove_100(target='Close')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# 2022-04-19 04:30:21.042 INFO    logs: setup() succesfully completed......................................
# 2022-04-19 04:30:21.194 INFO    logs: Initializing compare_models()
# 2022-04-19 04:30:21.195 INFO    logs: compare_models(include=None, fold=None, round=4, cross_validation=True, sort=MAE, n_select=1, budget_time=None, turbo=True, errors=ignore, fit_kwargs=None, groups=None, experiment_custom_tags=None, probability_threshold=None, verbose=True, display=None, exclude=None)
# 2022-04-19 04:30:21.197 INFO    logs: Checking exceptions
# 2022-04-19 04:30:21.198 INFO    logs: Preparing display monitor
# 2022-04-19 04:30:21.199 INFO    logs: Preparing display monitor
# IntProgress(value=0, description='Processing: ', max=94)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              04:30:21
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, MAE, MSE, RMSE, R2, RMSLE, MAPE, TT (Sec)]
# Index: []
# 2022-04-19 04:30:35.475 INFO    logs: Starting cross validation
# 2022-04-19 04:30:35.477 INFO    logs: Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=5), n_jobs=-1
# 2022-04-19 04:30:39.079 WARNING logs: create_model() for ridge raised an exception or returned all 0.0, trying without fit_kwargs:
# 2022-04-19 04:30:39.081 WARNING logs: joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/root/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 560, in _fit_and_score
#     test_scores = _score(estimator, X_test, y_test, scorer)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 607, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_scorer.py", line 88, in __call__
#     *args, **kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_scorer.py", line 213, in _score
#     **self._kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_regression.py", line 179, in mean_absolute_error
#     y_true, y_pred, multioutput)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_regression.py", line 86, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.7/site-packages/pycaret/internal/tabular.py", line 2203, in compare_models
#     model, model_fit_time = create_model_supervised(**create_model_args)
#   File "/root/venv/lib/python3.7/site-packages/pycaret/internal/tabular.py", line 3210, in create_model_supervised
#     error_score=0,
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 248, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 1056, in __call__
#     self.retrieve()
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 935, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/usr/local/lib/python3.7/concurrent/futures/_base.py", line 428, in result
#     return self.__get_result()
#   File "/usr/local/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
# 2022-04-19 04:30:39.082 INFO    logs: Initializing create_model()
# 2022-04-19 04:30:39.083 INFO    logs: create_model(estimator=ridge, fold=TimeSeriesSplit(max_train_size=None, n_splits=5), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f5b79823d10>, return_train_score=False, kwargs={})
# 2022-04-19 04:30:39.083 INFO    logs: Checking exceptions
# 2022-04-19 04:30:39.084 INFO    logs: Importing libraries
# 2022-04-19 04:30:39.084 INFO    logs: Copying training dataset
# 2022-04-19 04:30:39.087 INFO    logs: Defining folds
# 2022-04-19 04:30:39.087 INFO    logs: Declaring metric variables
# 2022-04-19 04:30:39.114 INFO    logs: Importing untrained model
# 2022-04-19 04:30:39.138 INFO    logs: Ridge Regression Imported succesfully
# 2022-04-19 04:30:39.208 INFO    logs: Starting cross validation
# 2022-04-19 04:30:39.209 INFO    logs: Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=5), n_jobs=-1
# 2022-04-19 04:30:42.777 ERROR   logs: create_model() for ridge raised an exception or returned all 0.0:
# 2022-04-19 04:30:42.780 ERROR   logs: joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 436, in _process_worker
#     r = call_item()
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 288, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/root/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 560, in _fit_and_score
#     test_scores = _score(estimator, X_test, y_test, scorer)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 607, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_scorer.py", line 88, in __call__
#     *args, **kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_scorer.py", line 213, in _score
#     **self._kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_regression.py", line 179, in mean_absolute_error
#     y_true, y_pred, multioutput)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/metrics/_regression.py", line 86, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/venv/lib/python3.7/site-packages/pycaret/internal/tabular.py", line 2212, in compare_models
#     model, model_fit_time = create_model_supervised(**create_model_args)
#   File "/root/venv/lib/python3.7/site-packages/pycaret/internal/tabular.py", line 3210, in create_model_supervised
#     error_score=0,
#   File "/root/venv/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/root/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 248, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 1056, in __call__
#     self.retrieve()
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/parallel.py", line 935, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/shared-libs/python3.7/py/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/usr/local/lib/python3.7/concurrent/futures/_base.py", line 435, in result
#     return self.__get_result()
#   File "/usr/local/lib/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
#
# 2022-04-19 04:30:42.781 INFO    logs: Initializing Elastic Net
# 2022-04-19 04:30:42.781 INFO    logs: Total runtime is 0.3582809607187907 minutes
# 2022-04-19 04:30:42.811 INFO    logs: SubProcess create_model() called ==================================
# 2022-04-19 04:30:42.814 INFO    logs: Initializing create_model()
# 2022-04-19 04:30:42.815 INFO    logs: create_model(estimator=en, fold=TimeSeriesSplit(max_train_size=None, n_splits=5), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f5b79823d10>, return_train_score=False, kwargs={})
# 2022-04-19 04:30:42.816 INFO    logs: Checking exceptions
# 2022-04-19 04:30:42.816 INFO    logs: Importing libraries
# 2022-04-19 04:30:42.817 INFO    logs: Copying training dataset
# 2022-04-19 04:30:42.820 INFO    logs: Defining folds
# 2022-04-19 04:30:42.822 INFO    logs: Declaring metric variables
# 2022-04-19 04:30:42.847 INFO    logs: Importing untrained model
# 2022-04-19 04:30:42.874 INFO    logs: Elastic Net Imported succesfully
# 2022-04-19 04:30:42.924 INFO    logs: Starting cross validation
# ...
# 2022-04-19 04:31:25.578 INFO    logs: Total runtime is 0.1217339555422465 minutes
# 2022-04-19 04:31:25.608 INFO    logs: SubProcess create_model() called ==================================
# 2022-04-19 04:31:25.609 INFO    logs: Initializing create_model()
# 2022-04-19 04:31:25.610 INFO    logs: create_model(estimator=et, fold=TimeSeriesSplit(max_train_size=None, n_splits=5), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f5b797ace50>, return_train_score=False, kwargs={})
# 2022-04-19 04:31:25.610 INFO    logs: Checking exceptions
# 2022-04-19 04:31:25.612 INFO    logs: Importing libraries
# 2022-04-19 04:31:25.613 INFO    logs: Copying training dataset
# 2022-04-19 04:31:25.614 INFO    logs: Defining folds
# 2022-04-19 04:31:25.615 INFO    logs: Declaring metric variables
# 2022-04-19 04:31:25.644 INFO    logs: Importing untrained model
# 2022-04-19 04:31:25.684 INFO    logs: Extra Trees Regressor Imported succesfully
# 2022-04-19 04:31:25.732 INFO    logs: Starting cross validation
# 2022-04-19 04:31:25.733 INFO    logs: Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=5), n_jobs=-1
# 2022-04-19 04:31:26.777 INFO    logs: Calculating mean and std
# 2022-04-19 04:31:26.779 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:26.788 INFO    logs: Uploading results into container
# 2022-04-19 04:31:26.789 INFO    logs: Uploading model into container now
# 2022-04-19 04:31:26.790 INFO    logs: create_model_container: 14
# 2022-04-19 04:31:26.791 INFO    logs: master_model_container: 14
# 2022-04-19 04:31:26.792 INFO    logs: display_container: 2
# 2022-04-19 04:31:26.794 INFO    logs: PowerTransformedTargetRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                                 max_depth=None, max_features='auto',
#                                 max_leaf_nodes=None, max_samples=None,
#                                 min_impurity_decrease=0.0,
#                                 min_impurity_split=None, min_samples_leaf=1,
#                                 min_samples_split=2,
#                                 min_weight_fraction_leaf=0.0, n_estimators=100,
#                                 n_jobs=-1, oob_score=False,
#                                 power_transformer_method='box-cox',
#                                 powe...
#                                 regressor=ExtraTreesRegressor(bootstrap=False,
#                                                               ccp_alpha=0.0,
#                                                               criterion='mse',
#                                                               max_depth=None,
#                                                               max_features='auto',
#                                                               max_leaf_nodes=None,
#                                                               max_samples=None,
#                                                               min_impurity_decrease=0.0,
#                                                               min_impurity_split=None,
#                                                               min_samples_leaf=1,
#                                                               min_samples_split=2,
#                                                               min_weight_fraction_leaf=0.0,
#                                                               n_estimators=100,
#                                                               n_jobs=-1,
#                                                               oob_score=False,
#                                                               random_state=2022,
#                                                               verbose=0,
#                                                               warm_start=False),
#                                 verbose=0, warm_start=False)
# 2022-04-19 04:31:26.795 INFO    logs: create_model() succesfully completed......................................
# 2022-04-19 04:31:26.958 INFO    logs: SubProcess create_model() end ==================================
# 2022-04-19 04:31:26.960 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:27.004 INFO    logs: Initializing AdaBoost Regressor
# 2022-04-19 04:31:27.005 INFO    logs: Total runtime is 0.14551820755004882 minutes
# 2022-04-19 04:31:27.035 INFO    logs: SubProcess create_model() called ==================================
# 2022-04-19 04:31:27.037 INFO    logs: Initializing create_model()
# 2022-04-19 04:31:27.038 INFO    logs: create_model(estimator=ada, fold=TimeSeriesSplit(max_train_size=None, n_splits=5), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f5b797ace50>, return_train_score=False, kwargs={})
# 2022-04-19 04:31:27.038 INFO    logs: Checking exceptions
# 2022-04-19 04:31:27.039 INFO    logs: Importing libraries
# 2022-04-19 04:31:27.040 INFO    logs: Copying training dataset
# 2022-04-19 04:31:27.041 INFO    logs: Defining folds
# 2022-04-19 04:31:27.042 INFO    logs: Declaring metric variables
# 2022-04-19 04:31:27.070 INFO    logs: Importing untrained model
# 2022-04-19 04:31:27.096 INFO    logs: AdaBoost Regressor Imported succesfully
# 2022-04-19 04:31:27.147 INFO    logs: Starting cross validation
# 2022-04-19 04:31:27.149 INFO    logs: Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=5), n_jobs=-1
# 2022-04-19 04:31:27.445 INFO    logs: Calculating mean and std
# 2022-04-19 04:31:27.446 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:27.456 INFO    logs: Uploading results into container
# 2022-04-19 04:31:27.457 INFO    logs: Uploading model into container now
# 2022-04-19 04:31:27.458 INFO    logs: create_model_container: 15
# 2022-04-19 04:31:27.458 INFO    logs: master_model_container: 15
# 2022-04-19 04:31:27.459 INFO    logs: display_container: 2
# 2022-04-19 04:31:27.461 INFO    logs: PowerTransformedTargetRegressor(base_estimator=None, learning_rate=1.0,
#                                 loss='linear', n_estimators=50,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 random_state=2022,
#                                 regressor=AdaBoostRegressor(base_estimator=None,
#                                                             learning_rate=1.0,
#                                                             loss='linear',
#                                                             n_estimators=50,
#                                                             random_state=2022))
# 2022-04-19 04:31:27.461 INFO    logs: create_model() succesfully completed......................................
# 2022-04-19 04:31:27.611 INFO    logs: SubProcess create_model() end ==================================
# 2022-04-19 04:31:27.613 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:27.640 INFO    logs: Initializing Gradient Boosting Regressor
# 2022-04-19 04:31:27.640 INFO    logs: Total runtime is 0.15610599517822266 minutes
# 2022-04-19 04:31:27.669 INFO    logs: SubProcess create_model() called ==================================
# 2022-04-19 04:31:27.670 INFO    logs: Initializing create_model()
# 2022-04-19 04:31:27.671 INFO    logs: create_model(estimator=gbr, fold=TimeSeriesSplit(max_train_size=None, n_splits=5), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f5b797ace50>, return_train_score=False, kwargs={})
# 2022-04-19 04:31:27.672 INFO    logs: Checking exceptions
# 2022-04-19 04:31:27.673 INFO    logs: Importing libraries
# 2022-04-19 04:31:27.674 INFO    logs: Copying training dataset
# 2022-04-19 04:31:27.676 INFO    logs: Defining folds
# 2022-04-19 04:31:27.677 INFO    logs: Declaring metric variables
# 2022-04-19 04:31:27.714 INFO    logs: Importing untrained model
# 2022-04-19 04:31:27.738 INFO    logs: Gradient Boosting Regressor Imported succesfully
# 2022-04-19 04:31:27.800 INFO    logs: Starting cross validation
# 2022-04-19 04:31:27.801 INFO    logs: Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=5), n_jobs=-1
# 2022-04-19 04:31:28.055 INFO    logs: Calculating mean and std
# 2022-04-19 04:31:28.057 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:28.064 INFO    logs: Uploading results into container
# 2022-04-19 04:31:28.067 INFO    logs: Uploading model into container now
# 2022-04-19 04:31:28.067 INFO    logs: create_model_container: 16
# 2022-04-19 04:31:28.068 INFO    logs: master_model_container: 16
# 2022-04-19 04:31:28.069 INFO    logs: display_container: 2
# 2022-04-19 04:31:28.071 INFO    logs: PowerTransformedTargetRegressor(alpha=0.9, ccp_alpha=0.0,
#                                 criterion='friedman_mse', init=None,
#                                 learning_rate=0.1, loss='ls', max_depth=3,
#                                 max_features=None, max_leaf_nodes=None,
#                                 min_impurity_decrease=0.0,
#                                 min_impurity_split=None, min_samples_leaf=1,
#                                 min_samples_split=2,
#                                 min_weight_fraction_leaf=0.0, n_estimators=100,
#                                 n_iter_no_change=None,
#                                 power_transformer_method...
#                                                                     max_leaf_nodes=None,
#                                                                     min_impurity_decrease=0.0,
#                                                                     min_impurity_split=None,
#                                                                     min_samples_leaf=1,
#                                                                     min_samples_split=2,
#                                                                     min_weight_fraction_leaf=0.0,
#                                                                     n_estimators=100,
#                                                                     n_iter_no_change=None,
#                                                                     presort='deprecated',
#                                                                     random_state=2022,
#                                                                     subsample=1.0,
#                                                                     tol=0.0001,
#                                                                     validation_fraction=0.1,
#                                                                     verbose=0,
#                                                                     warm_start=False),
#                                 subsample=1.0, tol=0.0001,
#                                 validation_fraction=0.1, verbose=0,
#                                 warm_start=False)
# 2022-04-19 04:31:28.074 INFO    logs: create_model() succesfully completed......................................
# 2022-04-19 04:31:28.227 INFO    logs: SubProcess create_model() end ==================================
# 2022-04-19 04:31:28.229 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:28.256 INFO    logs: Initializing Light Gradient Boosting Machine
# 2022-04-19 04:31:28.260 INFO    logs: Total runtime is 0.16643860737482707 minutes
# 2022-04-19 04:31:28.288 INFO    logs: SubProcess create_model() called ==================================
# 2022-04-19 04:31:28.289 INFO    logs: Initializing create_model()
# 2022-04-19 04:31:28.290 INFO    logs: create_model(estimator=lightgbm, fold=TimeSeriesSplit(max_train_size=None, n_splits=5), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f5b797ace50>, return_train_score=False, kwargs={})
# 2022-04-19 04:31:28.291 INFO    logs: Checking exceptions
# 2022-04-19 04:31:28.291 INFO    logs: Importing libraries
# 2022-04-19 04:31:28.293 INFO    logs: Copying training dataset
# 2022-04-19 04:31:28.295 INFO    logs: Defining folds
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=50.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2022-04-19 04:31:28.627 INFO    logs: create_model() succesfully completed......................................
# 2022-04-19 04:31:28.781 INFO    logs: SubProcess create_model() end ==================================
# 2022-04-19 04:31:28.783 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:28.811 INFO    logs: Initializing Dummy Regressor
# 2022-04-19 04:31:28.812 INFO    logs: Total runtime is 0.1756349841753642 minutes
# 2022-04-19 04:31:28.838 INFO    logs: SubProcess create_model() called ==================================
# 2022-04-19 04:31:28.839 INFO    logs: Initializing create_model()
# 2022-04-19 04:31:28.840 INFO    logs: create_model(estimator=dummy, fold=TimeSeriesSplit(max_train_size=None, n_splits=5), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f5b797ace50>, return_train_score=False, kwargs={})
# 2022-04-19 04:31:28.840 INFO    logs: Checking exceptions
# 2022-04-19 04:31:28.841 INFO    logs: Importing libraries
# 2022-04-19 04:31:28.842 INFO    logs: Copying training dataset
# 2022-04-19 04:31:28.843 INFO    logs: Defining folds
# 2022-04-19 04:31:28.844 INFO    logs: Declaring metric variables
# 2022-04-19 04:31:28.870 INFO    logs: Importing untrained model
# 2022-04-19 04:31:28.894 INFO    logs: Dummy Regressor Imported succesfully
# 2022-04-19 04:31:28.943 INFO    logs: Starting cross validation
# 2022-04-19 04:31:28.946 INFO    logs: Cross validating with TimeSeriesSplit(max_train_size=None, n_splits=5), n_jobs=-1
# 2022-04-19 04:31:29.014 INFO    logs: Calculating mean and std
# 2022-04-19 04:31:29.018 INFO    logs: Creating metrics dataframe
# 2022-04-19 04:31:29.029 INFO    logs: Uploading results into container
# 2022-04-19 04:31:29.033 INFO    logs: Uploading model into container now
# 2022-04-19 04:31:29.034 INFO    logs: create_model_container: 18
# 2022-04-19 04:31:29.035 INFO    logs: master_model_container: 18
# 2022-04-19 04:31:29.036 INFO    logs: display_container: 2
# 2022-04-19 04:31:29.038 INFO    logs: PowerTransformedTargetRegressor(constant=None,
#                                 power_transformer_method='box-cox',
#                                 power_transformer_standardize=True,
#                                 quantile=None,
#                                 regressor=DummyRegressor(constant=None,
#                                                          quantile=None,
#                                                          strategy='mean'),
#                                 strategy='mean')
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=50.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 2022-04-19 04:31:30.052 INFO    logs: save_model() successfully completed......................................
